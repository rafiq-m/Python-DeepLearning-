# %%
'''Machine learning engineers recommend to get the values between 0 and 1'''
import pandas as pd
import numpy as np

# %%
students= [{
    'Name':'Inam',
    'Course': 'AI'
},{
    'Name':'Ali',
    'Age' : 22,
    'Course': 'AI'
},
    {
    'Name':'Ali',
    'Age' : 22,
    'Course': 'AI'
},{
    'Name':'Mohsin',
    'Age' : 42,
},{
    'Name':'Daniyal',
    'Age' : 42,
    'Course': 'AI'
},{
    'Name':'Amir',
    'Age' : 22,
},
]
students
# Out:
# [{'Name': 'Inam', 'Course': 'AI'},
#  {'Name': 'Ali', 'Age': 22, 'Course': 'AI'},
#  {'Name': 'Ali', 'Age': 22, 'Course': 'AI'},
#  {'Name': 'Mohsin', 'Age': 42},
#  {'Name': 'Daniyal', 'Age': 42, 'Course': 'AI'},
#  {'Name': 'Amir', 'Age': 22}]

# %%
students_df = pd.DataFrame(students)
students_df
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
students_df.isnull()
# Out:
#      Age  Course   Name
# 0   True   False  False
# 1  False   False  False
# 2  False   False  False
# 3  False    True  False
# 4  False   False  False
# 5  False    True  False

# %%
students_df.notnull()
# Out:
#      Age  Course  Name
# 0  False    True  True
# 1   True    True  True
# 2   True    True  True
# 3   True   False  True
# 4   True    True  True
# 5   True   False  True

# %%
students_df.dropna()
# Out:
#     Age Course     Name
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 4  42.0     AI  Daniyal

# %%
students_df
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
students_df.ffill()
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0     AI   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0     AI     Amir

# %%
'''dropna will work in rowmeasure but if we set axis to 1 then it will delete the column'''
students_df.fillna(method ='bfill')
# Out:
#     Age Course     Name
# 0  22.0     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0     AI   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
students_df.fillna(5)
# Out:
#     Age Course     Name
# 0   5.0     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0      5   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0      5     Amir

# %%
students_df.fillna({'Age':students_df['Age'].mean(),'Course':'John Doe'})
# Out:
#     Age    Course     Name
# 0  30.0        AI     Inam
# 1  22.0        AI      Ali
# 2  22.0        AI      Ali
# 3  42.0  John Doe   Mohsin
# 4  42.0        AI  Daniyal
# 5  22.0  John Doe     Amir

# %%
df = pd.DataFrame(np.random.randn(6, 3))
df.iloc[2:, 1] = np.nan
df.iloc[4:, 2] = np.nan
df
# Out:
#           0         1         2
# 0 -0.545598 -0.658808  0.870904
# 1 -1.008629 -0.109356 -1.145431
# 2  0.379821       NaN  0.214204
# 3 -0.911381       NaN -0.302098
# 4 -0.426786       NaN       NaN
# 5 -0.633359       NaN       NaN

# %%
df.fillna(method='ffill', limit=2)
# Out:
#           0         1         2
# 0 -0.545598 -0.658808  0.870904
# 1 -1.008629 -0.109356 -1.145431
# 2  0.379821 -0.109356  0.214204
# 3 -0.911381 -0.109356 -0.302098
# 4 -0.426786       NaN -0.302098
# 5 -0.633359       NaN -0.302098

# %%
students_df
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
students_df.duplicated() #Koi cheez duplicate horahi ?
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
students_df
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
students_df.drop_duplicates()
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
students_df.drop_duplicates(keep = 'last')
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 2  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %% [markdown]
# # Mapping

# %%
'''map parameter me function leta he, map ka function utni baar chlega jitne records hain, map ka function ksi column per call hoga '''
filled_df = students_df.fillna({'Age':students_df['Age'].mean(),'Course':'John Doe'})
filled_df
# Out:
#     Age    Course     Name
# 0  30.0        AI     Inam
# 1  22.0        AI      Ali
# 2  22.0        AI      Ali
# 3  42.0  John Doe   Mohsin
# 4  42.0        AI  Daniyal
# 5  22.0  John Doe     Amir

# %%
drop_dup = filled_df.drop_duplicates(keep = 'last')
drop_dup
# Out:
#     Age    Course     Name
# 0  30.0        AI     Inam
# 2  22.0        AI      Ali
# 3  42.0  John Doe   Mohsin
# 4  42.0        AI  Daniyal
# 5  22.0  John Doe     Amir

# %%
twice_age = drop_dup['Age'].map(lambda val:val* 2)
twice_age
# Out:
# 0    60.0
# 2    44.0
# 3    84.0
# 4    84.0
# 5    44.0
# Name: Age, dtype: float64

# %%
 data = pd.DataFrame(np.arange(12).reshape((3, 4)),
 index=['Ohio', 'Colorado', 'New York'],
 columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data.columns = ['Karachi','Hyderabad','Badin','Sukkur']
data
# Out:
#           Karachi  Hyderabad  Badin  Sukkur
# Ohio            0          1      2       3
# Colorado        4          5      6       7
# New York        8          9     10      11

# %%
data.rename(index=str.title, columns=str.upper)
# Out:
#           KARACHI  HYDERABAD  BADIN  SUKKUR
# Ohio            0          1      2       3
# Colorado        4          5      6       7
# New York        8          9     10      11

# %% [markdown]
# # Discretiztion and Binning

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
bins = [18, 25, 35, 60, 100]
group_names = ['Youth','youthAdult','MiddleAged','Senior']

# %%
cats = pd.cut(ages, bins, labels = group_names)
cats
# Out:
# [Youth, Youth, Youth, youthAdult, Youth, ..., youthAdult, Senior, MiddleAged, MiddleAged, youthAdult]
# Length: 12
# Categories (4, object): [Youth < youthAdult < MiddleAged < Senior]

# %%
cats.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
cats.categories
# Out:
# Index(['Youth', 'youthAdult', 'MiddleAged', 'Senior'], dtype='object')

# %%
pd.value_counts(cats)
# Out:
# Youth         5
# MiddleAged    3
# youthAdult    3
# Senior        1
# dtype: int64

# %%
students_df
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
pd.value_counts(students_df['Course'])
# Out:
# AI    4
# Name: Course, dtype: int64

# %% [markdown]
# # DETECTING AND POTENTIAL OUTLIER

# %%
data = pd.DataFrame(np.random.randn(1000,4))
data
# Out:
#             0         1         2         3
# 0   -0.951477  0.873315  0.866975  0.198265
# 1   -0.905057 -0.391063  0.422065  0.488116
# 2   -0.438155 -0.146686  0.032902 -1.514182
# 3    1.061786  0.030363  1.717645  0.305022
# 4    0.274394  0.225105  0.054183  1.299064
# 5    0.258463  0.448417  0.439327  1.042326
# 6    0.017561  0.875678 -1.490763 -0.224537
# 7   -1.094568 -0.597040 -1.037693  1.923318
# 8    0.697708  1.585468 -0.952112  0.244814
# 9    0.451406 -0.412444 -1.506770 -0.576713
# 10  -1.522738 -0.394954 -0.183022  0.292064
# 11  -1.030664  0.696008 -0.107244 -0.338944
# 12  -0.087749 -0.622766 -0.734413 -0.598670
# 13   0.074638 -2.746700  1.792622 -0.188059
# 14  -0.705768  2.480021 -0.483984 -0.587793
# 15   2.428390 -0.435308  0.516497 -0.677798
# 16   0.265401 -1.230992  0.436420 -1.147832
# 17  -1.089756 -0.846623 -1.406872 -0.210337
# 18  -0.595332 -0.104007  1.058875 -1.439309
# 19  -0.240257  1.305655  0.089079 -1.785533
# ...

# %%
col = data[2]
col[np.abs(col) > 3]
# Out:
# 471    3.212487
# 493    3.187410
# 545    3.260912
# Name: 2, dtype: float64

# %%
df = pd.DataFrame(np.arange(5 * 4).reshape((5, 4)))
sampler = np.random.permutation(5)
sampler
# Out:
# array([2, 1, 0, 4, 3])

# %%
df.take(sampler)  #koi se bhi 5 values randomly dedega
# Out:
#     0   1   2   3
# 2   8   9  10  11
# 1   4   5   6   7
# 0   0   1   2   3
# 4  16  17  18  19
# 3  12  13  14  15

# %%
df.sample(n = 3)   #Koi se bhi 3 random samples return kardiye
# Out:
#     0   1   2   3
# 4  16  17  18  19
# 2   8   9  10  11
# 1   4   5   6   7

# %%
choices = pd.Series([5, 7, -1, 6, 4])
draws = choices.sample(n=5, replace = False)
draws    #replace true hoga tou value repeat karsakta otherwise not.
# Out:
# 3    6
# 1    7
# 2   -1
# 0    5
# 4    4
# dtype: int64

# %% [markdown]
# # DUMMY VARIABLES

# %%
students_df
# Out:
#     Age Course     Name
# 0   NaN     AI     Inam
# 1  22.0     AI      Ali
# 2  22.0     AI      Ali
# 3  42.0    NaN   Mohsin
# 4  42.0     AI  Daniyal
# 5  22.0    NaN     Amir

# %%
students_df.join(pd.get_dummies(students_df['Course']))   #2 series ko jorne ke liye join use karte
# Out:
#     Age Course     Name  AI
# 0   NaN     AI     Inam   1
# 1  22.0     AI      Ali   1
# 2  22.0     AI      Ali   1
# 3  42.0    NaN   Mohsin   0
# 4  42.0     AI  Daniyal   1
# 5  22.0    NaN     Amir   0

# %%
students_df['Name'].map(str.upper)
# Out:
# 0       INAM
# 1        ALI
# 2        ALI
# 3     MOHSIN
# 4    DANIYAL
# 5       AMIR
# Name: Name, dtype: object

# %% [markdown]
# # REGULAR EXPRESSION

# %%
'''Regular expression execute hone se pehle compile hoti he'''
import re

# %%
pattern = r'[A-Z0-9._%+-]+@[A-Z0-9.-]+\.[A-Z]{2,4}'  #Regular expression of email
text = """Dave dave@google.com
Steve steve@gmail.com
Rob rob@gmail.com
Ryan ryan@yahoo.com
"""
regex = re.compile(pattern, flags=re.IGNORECASE)

# %%
regex.findall(text)
# Out:
# ['dave@google.com', 'steve@gmail.com', 'rob@gmail.com', 'ryan@yahoo.com']

# %%
students_df['Name'].str.upper()
# Out:
# 0       INAM
# 1        ALI
# 2        ALI
# 3     MOHSIN
# 4    DANIYAL
# 5       AMIR
# Name: Name, dtype: object

# %%
data = pd.read_csv('AmazonCellphones.csv')

# %%
data
# Out:
#            asin     brand                                              title  \
# 0    B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1    B0009N5L7K  Motorola                                Motorola I265 phone
# 2    B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3    B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4    B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# 5    B001DCJAJG  Motorola      Motorola V365 no contract cellular phone AT&T
# 6    B001DZY4KI      Sony  Sony Ericsson G700 Triband GSM Phone Bronze (U...
# 7    B001GQ3DJM     Nokia                  Nokia 1680 Black Phone (T-Mobile)
# 8    B0027VKQPE     Nokia                        Nokia New 1100 for Tracfone
# 9    B00280QJFU   Samsung             Samsung T301G Prepaid Phone (Tracfone)
# 10   B0029X7UHC  Motorola              Motorola I205 cell phone nextel/Boost
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 9 columns):
# asin            792 non-null object
# brand           792 non-null object
# title           792 non-null object
# url             792 non-null object
# image           792 non-null object
# rating          792 non-null float64
# reviewUrl       792 non-null object
# totalReviews    792 non-null int64
# prices          577 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 55.8+ KB

# %%
data.describe()
# Out:
#            rating  totalReviews
# count  792.000000    792.000000
# mean     3.607576    104.231061
# std      0.668730    166.242503
# min      1.000000      1.000000
# 25%      3.200000      7.000000
# 50%      3.700000     31.500000
# 75%      4.000000    122.250000
# max      5.000000    984.000000

# %%
'''konse mobile sab se ziyada sale hue'''
data['brand'].value_counts().plot(kind = 'bar')

# %%
'''Rating 3 se kis ki kam he'''
rating = data['rating'] < 3
data2 = data[rating]

# %%
data2['brand'].value_counts().plot(kind = 'bar')

# %%
'''Nokia ki ratings ka mean kitna he '''
nokia = data[data['brand'] == 'Nokia']
nokia['rating'].mean()
# Out:
# 3.3224489795918366

# %%
samsung = data[data['brand'] == 'Samsung']
samsung['rating'].mean()
# Out:
# 3.573299748110832

# %%
'''tamam companies ke mean ko graph me plot karna he'''
ax = data.groupby('brand').mean()['rating'].sort_values().plot(kind = 'bar')

# %%
'''250 $ se 400$ tak phones konse hain'''
data['prices'].dropna()
# Out:
# 1                 $49.95
# 6                 $78.99
# 8                 $99.99
# 9                 $59.89
# 10                $99.95
# 11               $149.95
# 16                $79.00
# 19                $79.99
# 24                $59.95
# 26                $59.99
# 27               $109.99
# 28                $99.99
# 31               $118.80
# 35               $189.95
# 39                $89.00
# 40               $389.28
# 43               $181.49
# 45               $149.95
# 48                $99.99
# 49               $168.96
# 50               $164.92
# 55                $99.00
# 57                $84.94
# 61               $230.59
# 71               $183.44
# 74               $165.59
# 77       $142.99,$239.00
# 82               $209.65
# 83               $159.01
# 87               $142.99
#              ...
# 759              $499.99
# 760              $829.00
# 762              $346.70
# 764              $299.99
# 766              $309.99
# 767              $310.00
# ...
